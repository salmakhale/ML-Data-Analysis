# %% [markdown]
# <a href="https://colab.research.google.com/github/salmakhale/ML-Data-Analysis/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Califirnia Housing Price**

# %%
# Building a Regression MLP Using the Sequential API
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
# The House Prices Dataset
housing = fetch_california_housing()
print("Examples = ",housing.data.shape ," Labels = ", housing.target.shape)
# Out:
# Examples =  (20640, 8)  Labels =  (20640,)

# %%
X = housing.data
Y = housing.target

print("Example 0 : ",housing.data[0])
print("\nLabel 0 : ",housing.target[0])
# Out:
# Example 0 :  [   8.3252       41.            6.98412698    1.02380952  322.
#     2.55555556   37.88       -122.23      ]
#
# Label 0 :  4.526

# %%
Y[0]
# Out:
# 4.526

# %%
# Dataset to DataFrame
df = pd.DataFrame(housing.data, columns=housing.feature_names)
df["price"] = pd.Series(housing.target)
print("Info : \n",df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
# Info :
#  None

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
# Dropping the duplicate rows
duplicate_rows = df[df.duplicated()]
print("number of duplicate rows : ",duplicate_rows.shape)

# df.drop_duplicates(inplace=True)
# Out:
# number of duplicate rows :  (0, 9)

# %%
# To check missing values
print("SUM : \n",df.isnull().sum())
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap="viridis")
# Out:
# SUM :
#  MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# price         0
# dtype: int64
# <Axes: >

# %%
X_data = df.drop(["price"], axis=1).values
y_data = df["price"].values
print("X_data : ",X_data.shape," y_data : ",y_data.shape)
# Out:
# X_data :  (20640, 8)  y_data :  (20640,)

# %%
# Standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_data)
X_sts = scaler.transform(X_data)

# %%
# Split into Input and Output Elements
from sklearn.model_selection import train_test_split

X_train_full, X_test, y_train_full, y_test = train_test_split(X_sts,
              y_data, test_size= 0.20, random_state=100)
# Val set
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full
                                                      , test_size= 0.10)

print("X_train  = ",X_train.shape ," y_train = ", y_train.shape)
print("X_test   = ",X_test.shape ," y_test = ", y_test.shape)
print("X_valid  = ",X_valid.shape ," y_valid = ", y_valid.shape)
# Out:
# X_train  =  (14860, 8)  y_train =  (14860,)
# X_test   =  (4128, 8)  y_test =  (4128,)
# X_valid  =  (1652, 8)  y_valid =  (1652,)

# %%
type(X_train.shape[1:]),X_train.shape[1:]
# Out:
# (tuple, (8,))

# %%
# Creating the model using the Sequential API
model = keras.models.Sequential()
model.add(keras.layers.Dense(100, activation="relu", input_shape = X_train.shape[1:]))  # input_dim = 8
model.add(keras.layers.Dense(25, activation="relu"))
model.add(keras.layers.Dense(25, activation="relu"))
model.add(keras.layers.Dense(25, activation="relu"))
model.add(keras.layers.Dense(25, activation="relu"))
model.add(keras.layers.Dense(8, activation="relu"))
model.add(keras.layers.Dense(1, activation="relu")) # price > 0, so, relu

# The model’s summary() method displays all the model’s layers
#print(model.summary())
# Out:
# C:\Users\Nvidia\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compiling the model
# https://keras.io/models/sequential/
model.compile(loss="mean_squared_error", optimizer="sgd", metrics=["mae"])

# Training and evaluating the model
history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_valid, y_valid))
# history = model.fit(X_train, y_train, epochs=30, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9330 - mae: 1.0310 - val_loss: 0.5993 - val_mae: 0.5810
# Epoch 2/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5679 - mae: 0.5600 - val_loss: 0.4921 - val_mae: 0.5014
# Epoch 3/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4705 - mae: 0.4965 - val_loss: 0.6145 - val_mae: 0.6454
# Epoch 4/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4357 - mae: 0.4805 - val_loss: 0.5668 - val_mae: 0.5192
# Epoch 5/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4080 - mae: 0.4563 - val_loss: 0.5600 - val_mae: 0.5945
# Epoch 6/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3872 - mae: 0.4489 - val_loss: 0.4489 - val_mae: 0.5132
# Epoch 7/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3710 - mae: 0.4380 - val_loss: 0.3772 - val_mae: 0.4615
# Epoch 8/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3810 - mae: 0.4382 - val_loss: 0.3712 - val_mae: 0.4434
# Epoch 9/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3550 - mae: 0.4228 - val_loss: 0.3531 - val_mae: 0.4327
# Epoch 10/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3520 - mae: 0.4235 - val_loss: 0.7125 - val_mae: 0.6067
# Epoch 11/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3537 - mae: 0.4195 - val_loss: 0.3628 - val_mae: 0.4270
# Epoch 12/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3514 - mae: 0.4203 - val_loss: 0.9366 - val_mae: 0.7776
# Epoch 13/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3829 - mae: 0.4404 - val_loss: 0.3427 - val_mae: 0.3999
# Epoch 14/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3403 - mae: 0.4120 - val_loss: 0.3593 - val_mae: 0.4190
# Epoch 15/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3543 - mae: 0.4198 - val_loss: 0.3372 - val_mae: 0.4120
# Epoch 16/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3429 - mae: 0.4132 - val_loss: 0.4075 - val_mae: 0.4349
# Epoch 17/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3264 - mae: 0.4015 - val_loss: 0.4412 - val_mae: 0.5199
# Epoch 18/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3444 - mae: 0.4149 - val_loss: 0.3377 - val_mae: 0.4017
# Epoch 19/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3226 - mae: 0.4014 - val_loss: 0.3820 - val_mae: 0.4359
# Epoch 20/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3203 - mae: 0.3990 - val_loss: 0.3407 - val_mae: 0.4280
# Epoch 21/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3155 - mae: 0.3980 - val_loss: 0.3347 - val_mae: 0.4238
# Epoch 22/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3244 - mae: 0.4014 - val_loss: 0.7130 - val_mae: 0.6087
# Epoch 23/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3542 - mae: 0.4164 - val_loss: 0.4768 - val_mae: 0.5157
# Epoch 24/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3210 - mae: 0.3997 - val_loss: 0.3102 - val_mae: 0.3912
# Epoch 25/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3114 - mae: 0.3934 - val_loss: 0.3403 - val_mae: 0.4264
# Epoch 26/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3130 - mae: 0.3955 - val_loss: 0.5178 - val_mae: 0.5786
# Epoch 27/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3246 - mae: 0.4028 - val_loss: 0.3430 - val_mae: 0.4013
# Epoch 28/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3048 - mae: 0.3882 - val_loss: 0.3012 - val_mae: 0.3760
# Epoch 29/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3130 - mae: 0.3922 - val_loss: 0.3178 - val_mae: 0.3976
# Epoch 30/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3093 - mae: 0.3887 - val_loss: 0.4376 - val_mae: 0.4456
# Epoch 31/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3078 - mae: 0.3878 - val_loss: 0.5916 - val_mae: 0.6115
# Epoch 32/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3319 - mae: 0.4061 - val_loss: 0.3405 - val_mae: 0.4013
# Epoch 33/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2975 - mae: 0.3808 - val_loss: 0.3241 - val_mae: 0.3820
# Epoch 34/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3129 - mae: 0.3909 - val_loss: 0.3338 - val_mae: 0.3954
# Epoch 35/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3126 - mae: 0.3882 - val_loss: 0.3380 - val_mae: 0.4169
# Epoch 36/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3006 - mae: 0.3838 - val_loss: 0.3558 - val_mae: 0.4497
# Epoch 37/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2953 - mae: 0.3793 - val_loss: 0.3681 - val_mae: 0.4165
# Epoch 38/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2800 - mae: 0.3714 - val_loss: 0.3116 - val_mae: 0.3845
# Epoch 39/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3085 - mae: 0.3880 - val_loss: 0.3058 - val_mae: 0.3846
# Epoch 40/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3100 - mae: 0.3869 - val_loss: 0.4994 - val_mae: 0.5442
# Epoch 41/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3110 - mae: 0.3908 - val_loss: 0.3370 - val_mae: 0.3857
# Epoch 42/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2875 - mae: 0.3773 - val_loss: 0.6589 - val_mae: 0.5738
# Epoch 43/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3019 - mae: 0.3829 - val_loss: 0.3146 - val_mae: 0.3786
# Epoch 44/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2883 - mae: 0.3749 - val_loss: 0.5623 - val_mae: 0.5016
# Epoch 45/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3020 - mae: 0.3821 - val_loss: 0.3047 - val_mae: 0.3961
# Epoch 46/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2926 - mae: 0.3774 - val_loss: 0.3014 - val_mae: 0.3781
# Epoch 47/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2971 - mae: 0.3793 - val_loss: 0.3344 - val_mae: 0.3852
# Epoch 48/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2814 - mae: 0.3710 - val_loss: 0.2951 - val_mae: 0.3763
# Epoch 49/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2811 - mae: 0.3674 - val_loss: 0.3853 - val_mae: 0.4294
# Epoch 50/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2876 - mae: 0.3730 - val_loss: 0.3331 - val_mae: 0.4118
# Epoch 51/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2945 - mae: 0.3758 - val_loss: 0.3567 - val_mae: 0.4435
# Epoch 52/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2920 - mae: 0.3808 - val_loss: 0.3018 - val_mae: 0.3946
# Epoch 53/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2867 - mae: 0.3697 - val_loss: 0.5380 - val_mae: 0.4970
# Epoch 54/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2926 - mae: 0.3748 - val_loss: 0.3744 - val_mae: 0.4045
# Epoch 55/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2816 - mae: 0.3685 - val_loss: 0.3864 - val_mae: 0.4230
# Epoch 56/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2759 - mae: 0.3653 - val_loss: 0.6385 - val_mae: 0.5429
# Epoch 57/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2853 - mae: 0.3709 - val_loss: 0.2988 - val_mae: 0.3769
# Epoch 58/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2875 - mae: 0.3698 - val_loss: 0.5007 - val_mae: 0.5634
# Epoch 59/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2903 - mae: 0.3760 - val_loss: 0.3766 - val_mae: 0.4289
# Epoch 60/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2619 - mae: 0.3540 - val_loss: 0.3055 - val_mae: 0.3800
# Epoch 61/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2788 - mae: 0.3685 - val_loss: 0.4548 - val_mae: 0.4616
# Epoch 62/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2803 - mae: 0.3637 - val_loss: 0.3220 - val_mae: 0.3774
# Epoch 63/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2897 - mae: 0.3711 - val_loss: 0.3554 - val_mae: 0.4367
# Epoch 64/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2884 - mae: 0.3710 - val_loss: 0.4969 - val_mae: 0.4818
# Epoch 65/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2852 - mae: 0.3696 - val_loss: 0.5003 - val_mae: 0.5659
# Epoch 66/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2845 - mae: 0.3698 - val_loss: 0.3507 - val_mae: 0.4333
# Epoch 67/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2742 - mae: 0.3593 - val_loss: 0.3617 - val_mae: 0.3970
# Epoch 68/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2792 - mae: 0.3629 - val_loss: 0.5359 - val_mae: 0.5132
# Epoch 69/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2817 - mae: 0.3653 - val_loss: 0.2876 - val_mae: 0.3710
# Epoch 70/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2770 - mae: 0.3649 - val_loss: 0.2850 - val_mae: 0.3722
# Epoch 71/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2648 - mae: 0.3571 - val_loss: 0.4242 - val_mae: 0.4303
# Epoch 72/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2821 - mae: 0.3688 - val_loss: 3.5790 - val_mae: 1.5654
# Epoch 73/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4893 - mae: 0.4604 - val_loss: 0.2878 - val_mae: 0.3610
# Epoch 74/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2573 - mae: 0.3501 - val_loss: 0.4211 - val_mae: 0.4867
# Epoch 75/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2852 - mae: 0.3677 - val_loss: 0.2952 - val_mae: 0.3922
# Epoch 76/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2731 - mae: 0.3605 - val_loss: 0.3021 - val_mae: 0.3894
# Epoch 77/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2673 - mae: 0.3555 - val_loss: 0.3046 - val_mae: 0.3781
# Epoch 78/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2727 - mae: 0.3563 - val_loss: 0.6341 - val_mae: 0.5351
# Epoch 79/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2856 - mae: 0.3674 - val_loss: 0.5193 - val_mae: 0.5049
# Epoch 80/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2747 - mae: 0.3588 - val_loss: 0.3945 - val_mae: 0.4184
# Epoch 81/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2724 - mae: 0.3605 - val_loss: 0.4822 - val_mae: 0.4666
# Epoch 82/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2907 - mae: 0.3700 - val_loss: 0.4665 - val_mae: 0.4576
# Epoch 83/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2825 - mae: 0.3633 - val_loss: 0.5030 - val_mae: 0.4943
# Epoch 84/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2936 - mae: 0.3704 - val_loss: 0.3141 - val_mae: 0.3987
# Epoch 85/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2734 - mae: 0.3634 - val_loss: 0.7070 - val_mae: 0.6349
# Epoch 86/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2957 - mae: 0.3717 - val_loss: 0.3121 - val_mae: 0.3665
# Epoch 87/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2728 - mae: 0.3581 - val_loss: 0.2768 - val_mae: 0.3592
# Epoch 88/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2613 - mae: 0.3494 - val_loss: 0.3341 - val_mae: 0.3788
# Epoch 89/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2500 - mae: 0.3448 - val_loss: 0.2827 - val_mae: 0.3578
# Epoch 90/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2427 - mae: 0.3381 - val_loss: 0.2852 - val_mae: 0.3615
# Epoch 91/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2470 - mae: 0.3437 - val_loss: 0.4355 - val_mae: 0.4457
# Epoch 92/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2782 - mae: 0.3589 - val_loss: 0.3799 - val_mae: 0.4100
# Epoch 93/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2654 - mae: 0.3507 - val_loss: 0.3368 - val_mae: 0.3885
# Epoch 94/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2557 - mae: 0.3472 - val_loss: 0.3205 - val_mae: 0.3835
# Epoch 95/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
#   0.385153204202652,
#   0.3763332664966583,
#   0.4294256269931793,
#   0.41178277134895325,
#   0.4434761106967926,
#   0.3946041762828827,
#   0.49698102474212646,
#   0.4045276641845703,
#   0.4229733347892761,
#   0.5429157018661499,
#   0.37694162130355835,
#   0.563448429107666,
#   0.42893779277801514,
#   0.3799620270729065,
#   0.4616359770298004,
#   0.3773941993713379,
#   0.43672117590904236,
#   0.48183614015579224,
#   0.5658769011497498,
#   0.4333449602127075,
#   0.3969901204109192,
#   0.5131883025169373,
#   0.37097442150115967,
#   0.3722009062767029,
#   0.43029123544692993,
#   1.5654488801956177,
#   0.3610250651836395,
#   0.48671284317970276,
#   0.3921731114387512,
#   0.38940244913101196,
#   0.3781450092792511,
#   0.5351405739784241,
#   0.504909098148346,
#   0.41837477684020996,
#   0.46659696102142334,
#   0.4575839340686798,
#   0.4943050444126129,
#   0.398723304271698,
#   0.634887158870697,
#   0.3665342628955841,
#   0.3591638207435608,
#   0.3788100779056549,
#   0.35782867670059204,
#   0.36154434084892273,
#   0.4457167983055115,
#   0.40996038913726807,
#   0.3885035514831543,
#   0.383505642414093,
#   0.4410496950149536,
#   0.3739815354347229,
#   0.36696305871009827,
#   0.4198903739452362,
#   0.3699636459350586,
#   0.5031750202178955]}

# %%
# plot the learning curves
import pandas as pd
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot(figsize=(12, 8))
plt.grid(True)
#plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

print("-----------------------------------------------------------------------")
# Evaluate the model
model_evaluate = model.evaluate(X_test, y_test)
print("Loss                   : ",model_evaluate[0])
print("Mean Absolute Error     : ",model_evaluate[1])
# Out:
# -----------------------------------------------------------------------
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 0.5497 - mae: 0.4909
# Loss                   :  0.5573840141296387
# Mean Absolute Error     :  0.494515061378479

# %%
# Comparison of the actual results with the predicted results
predicted = model.predict(X_test)

# Model evaluation
print("Mean Absolute Error    : ", metrics.mean_absolute_error(y_test, predicted))
print("Mean Squared Error     : ", metrics.mean_squared_error(y_test, predicted))
print("Root Mean Squared Error: ", np.sqrt(metrics.mean_squared_error(y_test, predicted)))
print("r2_score               : ", metrics.r2_score(y_test, predicted))

print("-----------------------------------------------------------------------")
df_data = pd.DataFrame({"Actual": y_test.flatten(), "Predicted": predicted.flatten()})
print(df_data.head(15))
print("-----------------------------------------------------------------------")
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# Mean Absolute Error    :  0.4945150471748585
# Mean Squared Error     :  0.5573840698032267
# Root Mean Squared Error:  0.7465815895153234
# r2_score               :  0.5863253637697883
# -----------------------------------------------------------------------
#     Actual  Predicted
# 0    2.453   2.291268
# 1    1.042   0.786781
# 2    1.462   1.371894
# 3    1.542   0.880362
# 4    3.242   1.337260
# 5    1.411   1.187163
# 6    2.273   1.744284
# 7    2.023   2.324672
# 8    1.702   0.833275
# 9    3.018   2.455917
# 10   1.522   1.245060
# 11   3.081   3.127561
# 12   4.850   4.331577
# 13   1.625   2.274115
# 14   2.250   2.382254
# -----------------------------------------------------------------------
